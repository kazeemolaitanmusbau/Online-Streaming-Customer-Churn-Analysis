# %% [markdown]
# # Title: Online Streaming customer Churn Analysis
#
# ## Table of Contents
#     1. Problem statement
#     2. Importaion of package and dataset
#     3. Data Accessing
#     4. Data Cleaning
#     5. Exploration Data Analysis
#     6. Features Engineering and Transformation
#     7. Building Model
#     8. Conclusion
#     9. Reference

# %%
# 2

# %%
# importation of the packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# read the dataset into dataframe
churn_df = pd.read_csv("C:/Users/pc/Desktop/1/my project/Churn/churn.csv")

# %% [markdown]
# # Data Accessing

# %%
# print the first five rows of the dataframe
churn_df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
# print the last five rows of the dataframe
churn_df.tail()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
# randomly print the 5 rows from dataframe
churn_df.sample(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 6037  7537-CBQUZ    Male              1      No         No      63
# 611   4765-OXPPD  Female              0     Yes        Yes       9
# 621   0516-UXRMT  Female              0      No         No      62
# 615   9396-ZSFLL  Female              0      No         No      15
# 3513  4063-EIKNQ    Male              0     Yes        Yes      11
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 6037          Yes           Yes     Fiber optic                  Yes  ...
# 611           Yes            No             DSL                  Yes  ...
# 621           Yes           Yes     Fiber optic                  Yes  ...
# 615           Yes           Yes             DSL                   No  ...
# 3513          Yes            No              No  No internet service  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# ...

# %%
# check the summary of the dataframe
churn_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
# check for missing values
churn_df.isna().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
# check for duplicate entries
churn_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Data Cleaning

# %%
#churn_df["TotalCharges"] =churn_df["TotalCharges"].astype(object).astype(float)

# %% [markdown]
# # Exploration Data Analysis

# %%
churn_df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
churn_df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
gender_count.values
# Out:
# array([3555, 3488], dtype=int64)

# %%
# count of gender
gender_count=churn_df.gender.value_counts()
sns.barplot(x=gender_count.index, y=gender_count.values)
plt.title("count of gender")
plt.ylabel("Count")
plt.xlabel("Gender")
plt.show()

# %%
churn_df["tenure"].plot(kind="box")
# Out:
# <AxesSubplot:>

# %%
churn_df["tenure"].plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sns.kdeplot(churn_df["tenure"])
# Out:
# <AxesSubplot:xlabel='tenure', ylabel='Density'>

# %%
sns.kdeplot(churn_df["MonthlyCharges"])
# Out:
# <AxesSubplot:xlabel='MonthlyCharges', ylabel='Density'>

# %%
# get all the category column and drop unwanted columns
col_dummie=churn_df.select_dtypes(include="object").drop(["TotalCharges", "customerID", "Churn"], axis=1).columns
col_dummie
# Out:
# Index(['gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod'],
#       dtype='object')

# %%
# convert all the category columns to dummies
clean_df=pd.get_dummies(churn_df, columns=col_dummie)

# %%
clean_df.drop("customerID", inplace=True, axis=1)

# %% [markdown]
# # Over Sampling

# %%
y.value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
majority=clean_df.query("Churn == 'No' ")
minority=clean_df.query("Churn==  'Yes'   ")

# %%
from sklearn.utils import resample
# upgrade the minority class the level of majority
over_sam=resample(minority ,n_samples=len(majority), random_state=42)

# %%
# join the majority with the over_sam
clean_df_over=pd.concat([over_sam, majority], ignore_index=True)

# %%
clean_df_over.Churn.value_counts()
# Out:
# Yes    5174
# No     5174
# Name: Churn, dtype: int64

# %%
# split the data into features and target
y= clean_df_over.pop("Churn")
X= clean_df_over.copy()

# %%
y.value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
from sklearn.model_selection import
